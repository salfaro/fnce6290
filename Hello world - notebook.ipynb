# %%
print('this is a test 2')
# Out:
# this is a test 2

# %%
#This is a comment
def testing():
    return 'hello world 2'

# %%
string = testing()

# %%
print(string)
# Out:
# hello world 2

# %% [raw]
# # ejemplo
