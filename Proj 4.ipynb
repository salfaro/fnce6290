# %%
#Make sure to install xlrd 1.2:   pip install xlrd==1.2.0
import xlrd
import pandas as pd
import numpy as np
from scipy import stats
from random import randrange
import random
import matplotlib.pyplot as plt
import matplotlib.ticker as tck
import matplotlib.mlab as mlab
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
import seaborn as sns

# %%
file = ('/Users/alfaro/Documents/pythoncode/master/metodoscuantitativos/New_SRI_Fund_Data2020-1_cleaned.xlsx')

# %%
df1 = pd.read_excel(file, sheet_name='Non_SRI Large Funds Data')
df2 = pd.read_excel(file, sheet_name='Index Data')
df3 = pd.read_excel(file, sheet_name='SRI Data')

# %%
df1
# Out:
#    Ticker                                        Fund Name  \
# 0   VTSMX           Vanguard Total Stock Market Index Fund
# 1   VFINX                          Vanguard 500 Index Fund
# 2   VINIX                Vanguard Institutional Index Fund
# 3   AGTHX       American Funds The Growth Fund of America®
# 4   AWSHX  American Funds Washington Mutual Investors Fund
# ..    ...                                              ...
# 59  HLGEX                     JPMorgan Mid Cap Growth Fund
# 60  TWHIX                   American Century Heritage Fund
# 61  VMGRX                          Vanguard Mid-Cap Growth
# 62  BARAX                                 Baron Asset Fund
# 63  DFVEX                      DFA U.S. Vector Equity Fund
#
#                 Primary Category Inception Date  Net Assets ($M USD)  \
# 0    U.S. Large-Cap Blend Equity     1992-04-27            901896.02
# 1    U.S. Large-Cap Blend Equity     1976-08-31            538164.31
# ...

# %%
df1.groupby(['Primary Category']).size()
# Out:
# Primary Category
# North America Equity             3
# U.S. Large-Cap Blend Equity     10
# U.S. Large-Cap Growth Equity     9
# U.S. Large-Cap Value Equity      7
# U.S. Mid-Cap Blend Equity        6
# U.S. Mid-Cap Growth Equity      19
# U.S. Mid-Cap Value Equity       10
# dtype: int64

# %%
df3.groupby(['Fund Type']).size()
# Out:
# Fund Type
# Equity Large Cap     25
# Equity Mid-Sm Cap    12
# dtype: int64
